# %%
# !pip install yfinance reportlab pandas
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: reportlab in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (4.3.1)
# Requirement already satisfied: pandas in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from yfinance) (2.0.1)
# Requirement already satisfied: requests>=2.31 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from yfinance) (2024.1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 23.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from yfinance) (6.30.2)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: pillow>=9.0.0 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from reportlab) (9.4.0)
# Requirement already satisfied: chardet in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from reportlab) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: pycparser in /Users/victormpreciado/anaconda3/envs/torchgeo/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Downloading yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 80.2 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Downloading websockets-15.0.1-cp311-cp311-macosx_11_0_arm64.whl (173 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15605 sha256=95352f9414f5c19d1250d1ebe910d65999e1480e79fed44b6ef29e6976dd749a
#   Stored in directory: /Users/victormpreciado/Library/Caches/pip/wheels/42/d6/84/bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.18.2-cp311-cp311-macosx_11_0_arm64.whl size=264614 sha256=1cb349ed8995f768fb8a528734e5de06b0564bcc486209fe64109a3c0ecdb2b6
#   Stored in directory: /Users/victormpreciado/Library/Caches/pip/wheels/28/84/61/758d1bd7b9c9d700158c8642a8aff2a9bf2e1ae69641c40784
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, frozendict, curl_cffi, yfinance
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.6 multitasking-0.0.12 peewee-3.18.2 websockets-15.0.1 yfinance-0.2.65

# %%
import yfinance as yf
import io

# Download Google's stock price history (raw values, not auto-adjusted)
df = yf.download("GOOG", start="2020-01-01", end="2023-12-31", auto_adjust=False)

# Flatten column names (avoid MultiIndex)
df.columns = [col[0] for col in df.columns]

# Display DataFrame info
buffer = io.StringIO()
df.info(buf=buffer)
print(buffer.getvalue())

# Display first rows
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2020-01-02 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  1006 non-null   float64
#  1   Close      1006 non-null   float64
#  2   High       1006 non-null   float64
#  3   Low        1006 non-null   float64
#  4   Open       1006 non-null   float64
#  5   Volume     1006 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 55.0 KB
#             Adj Close      Close       High        Low       Open    Volume
# Date
# 2020-01-02  67.964508  68.368500  68.406998  67.077499  67.077499  28132000
# 2020-01-03  67.630981  68.032997  68.625000  67.277199  67.392998  23728000
# 2020-01-06  69.298584  69.710503  69.824997  67.500000  67.500000  34646000
# 2020-01-07  69.255341  69.667000  70.149498  69.518997  69.897003  30054000
# 2020-01-08  69.801102  70.216003  70.579002  69.542000  69.603996  30560000
